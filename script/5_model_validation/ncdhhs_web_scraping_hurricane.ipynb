# %%
# ----------------------------------------
# Python Script to web scrap validation dataset from NCDHHS E. coli testing results
# Author: Jennifer Zhang
# Last edited: 2025-07-23
# ----------------------------------------

import requests
from bs4 import BeautifulSoup
import pdfplumber
import fitz
import re
import csv
import os
from geocodio import GeocodioClient
import pandas as pd

# %%
# Fetch and parse the NCDHHS Hurricane Helene test results website
base_url = 'https://celr.dph.ncdhhs.gov/hurricaneHelene'
response = requests.get(base_url)
soup = BeautifulSoup(response.content, 'html.parser')

# Find county IDs
county_IDs = []
counties = soup.find('select', id='client.rasclientId')
for county in counties.find_all('option'):
    id = county['value']
    if len(id) > 0: # Ignores ***Select*** option's empty value
        id = id.replace(" ", "+")
        county_IDs.append(id)
    # print(county.text.strip())
# print(county_IDs)

with open("county_ids_hurricane.txt", "w") as f:
    for county_id in county_IDs:
        f.write(f"{county_id}\n")

# %%
# Loop through county pages and scrape PDF links
county_IDs = open("county_ids_hurricane.txt").read().splitlines()
pdf_links = []

for county_id in county_IDs:
    url = f"{base_url}?client.rasclientId={county_id}&filterBy=1&recentDay=5&docFrom=&docTo="
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    if not soup.find_all('div', class_='text-error'):
        for sample in soup.find_all('a', href=True, target='_blank'):
            pdf_links.append(sample['href'])

with open("pdf_links_hurricane.txt", "w") as f:
    for link in pdf_links:
        f.write(f"{link}\n")

# %%
def extract_text_from_pdf(pdf_path):
    # Parse the PDF
    with pdfplumber.open(pdf_path) as pdf:
        text = pdf.pages[0].extract_text()

    doc = fitz.open("temp.pdf")

    data = {
        "System_Name": re.search(r"Name of System:\s*([A-Z0-9\s&.,\-]+)", text), # get rid of non-all caps text afterwards
        "Street_Address": None,  # Placeholders for address
        "City": None,
        "State": None,
        "Zip": None,
        "EIN": re.search(r"EIN:\s?(\S+)", text),
        "StarLiMS_ID": re.search(r"StarLiMS ID:\s*(\S+)", text),
        "Date_Collected": re.search(r"Date Collected:\s*(\d{2}/\d{2}/\d{4})", text),
        "Time_Collected": re.search(r"Time Collected:\s*(\d{2}:\d{2})", text),
        "Date_Received": re.search(r"Date Received:\s*(\d{2}/\d{2}/\d{4})", text),
        "Time_Received": re.search(r"Time Received:\s*(\d{2}:\d{2})", text),
        "Sampling_Point": re.search(r"Sampling Point:\s*(.*?)\n", text),
        "Sample_Type": re.search(r"Sample Type:\s*(Treated|[\w\s]+?)\s+GPS No\.", text),
        "Treatment": re.search(r"Treatment:\s*(Chlorinated|[\w\s]+?)\s+Well Permit No\.", text),
        "Days_Since_Treatment": re.search(r"Days Since Chlorine Treatment\s*(.*?)\n", text),
        # "Days_Since_Treatment": re.search(r"Days Since Chlorine Treatment\s*(Unknown/Not Given|<= 7 Days|>7 Days)\n", text),
        "Comment": re.search(r"Comment:\s*(.*?)\nColi", text),
        "Colilert_Method": re.search(r"Method:\s*(.*?)\n", text),
        "Total_Coliform_Result": re.search(r"Total Coliform\s+(Absent|Present|Not Tested|[0-9<>.,]+)(?=\s+)", text),
        "Total_Coliform_Date": re.search(r"Total Coliform\s+\w+\s+(\d{2}/\d{2}/\d{4})", text),
        "Ecoli_Result": re.search(r"E\. coli\s+(Absent|Present|Not Tested|[0-9<>.,]+)(?=\s+)", text),
        "Ecoli_Date": re.search(r"E\. coli\s+\w+\s+(\d{2}/\d{2}/\d{4})", text),
    }

    # Clean up and finalize regex values
    cleaned_data = {k: (v.group(1).strip() if v else "") for k, v in data.items()}

    # Add address extraction logic
    street_line = None
    city_line = None

    # Define tight coordinate ranges with a little tolerance
    x_range = (415, 420)
    street_y_range = (158, 162)
    city_y_range = (189, 192)

    for page in doc:
        blocks = page.get_text("blocks")

        for block in blocks:
            x0 = block[0]
            y0 = block[1]
            text = block[4].strip()

            if x_range[0] <= x0 <= x_range[1] and street_y_range[0] <= y0 <= street_y_range[1]:
                street_line = text

            elif x_range[0] <= x0 <= x_range[1] and city_y_range[0] <= y0 <= city_y_range[1]:
                city_line = text

    if street_line and city_line:
        # Extract street only (remove possible names after the address)
        street = street_line.strip().split('\n', 1)[0]
        if street:
            cleaned_data["Street_Address"] = street
        else:
            cleaned_data["Street_Address"] = ""
            print(f"Warning: Street address not found for {cleaned_data['StarLiMS_ID']}")

        # Extract city, state, zip
        city_match = re.search(r'([A-Za-z\s]+),\s+([A-Z]{2})\s+(\d{5})', city_line)        
        
        if city_match:
            city, state, zip_code = city_match.groups()
            cleaned_data["City"] = city.strip()
            cleaned_data["State"] = state
            cleaned_data["Zip"] = zip_code
        else:
            cleaned_data["City"] = ""
            cleaned_data["State"] = ""
            cleaned_data["Zip"] = ""
            print(f"Warning: City, state, or zip not found for {cleaned_data['StarLiMS_ID']}")

    return cleaned_data

# %% [markdown]
# Test extract_text()

# %%
link = 'showReportPublic?folderNo=ES250211-0076&org=v11'
url = f"https://celr.dph.ncdhhs.gov/{link}"
pdf_response = requests.get(url)
with open("temp.pdf", "wb") as f:
    f.write(pdf_response.content)

with pdfplumber.open("temp.pdf") as pdf:
    text = pdf.pages[0].extract_text()
# print(text)

extracted_text = extract_text_from_pdf(pdf_path="temp.pdf")
# print(extracted_text)
# Out:
# 4312 District Drive
# North Carolina State Laboratory of Public Health MSC 1918
# Raleigh, NC 27699-1918
# Environmental Sciences
# http://slph.ncpublichealth.com
# Phone: 919-733-7308
# Microbiology
# Fax: 919-715-8611
# Certificate of Analysis
# FINAL REPORT
# Report to: Jason Pierce Name of System:
# ALLEGHANY CO ENVIRONMENTAL HEALTH Doug Cox
# PO BOX 309 3490 Chestnut Grove
# Sparta, NC 28675 Sparta, NC 28675
# EIN: 566001534EH Delivery: NC Courier Alleghany County
# StarLiMS ID: ES250211-0076 Date Collected: 02/10/2025 Time Collected: 09:30 By: Doug Cox
# Date Received: 02/11/2025 Time Received: 08:02 By: Julie Schiavone
# Barcode ID: 000714
# Sample Source: Hurricane Helene Sampling Point: Bathroom sink
# Sample Type: GPS No.
# Treatment: Well Permit No.
# Days Since Chlorine Treatment Unknown/Not Given
# Comment: Water source: Spring
# Colilert - Quanti-Tray2000 Profile Method: SM 9223B
# Analyte Test Result Unit Conclusion Date Tested
# Total Coliform 16 MPN/100mL 02/11/2025
# E. coli <1 MPN/100mL 02/11/2025
# Report Date: 02/12/2025 Reported By: KKURTZ
# Explanations of Coliform Analysis:
# If coliform bacteria are Absent, the water is considered safe for drinking purpose. If coliform bacteria are Present, the water is considered unsafe for
# drinking purpose. Presence of E. coli (bacteria) generally indicates that the water has been contaminated with fecal material. It must be remembered that a
# water analysis refers only to the sample received and should not be regarded as a complete report on the water supply.
# Page 1 of 1
# {'System_Name': 'ALLEGHANY CO ENVIRONMENTAL HEALTH D', 'Street_Address': '3490 Chestnut Grove', 'City': 'Sparta', 'State': 'NC', 'Zip': '28675', 'EIN': '566001534EH', 'StarLiMS_ID': 'ES250211-0076', 'Date_Collected': '02/10/2025', 'Time_Collected': '09:30', 'Date_Received': '02/11/2025', 'Time_Received': '08:02', 'Sampling_Point': 'Bathroom sink', 'Sample_Type': '', 'Treatment': '', 'Days_Since_Treatment': 'Unknown/Not Given', 'Comment': 'Water source: Spring', 'Colilert_Method': 'SM 9223B', 'Total_Coliform_Result': '16', 'Total_Coliform_Date': '', 'Ecoli_Result': '<1', 'Ecoli_Date': ''}

# %%
all_data = []
pdf_links = open("pdf_links_hurricane.txt").read().splitlines()

# Loop through the PDF links
for link in pdf_links:
    print(f"Processing {link}...")
    
    # Download the PDFs
    url = f"https://celr.dph.ncdhhs.gov/{link}"
    pdf_response = requests.get(url)
    with open("temp.pdf", "wb") as f:
        f.write(pdf_response.content)

    # Extract text from the PDF
    extracted_text = extract_text_from_pdf("temp.pdf")
    os.remove("temp.pdf")

    all_data.append(extracted_text)
# Out:
# Processing showReportPublic?folderNo=ES250430-0059&org=v11...
# Processing showReportPublic?folderNo=ES250415-0053&org=v11...
# Processing showReportPublic?folderNo=ES250327-0059&org=v11...
# Processing showReportPublic?folderNo=ES250327-0060&org=v11...
# Processing showReportPublic?folderNo=ES250325-0047&org=v11...
# Processing showReportPublic?folderNo=ES250304-0034&org=v11...
# Processing showReportPublic?folderNo=ES250226-0050&org=v11...
# Processing showReportPublic?folderNo=ES250219-0113&org=v11...
# Processing showReportPublic?folderNo=ES250211-0076&org=v11...
# Processing showReportPublic?folderNo=ES250130-0094&org=v11...
# Processing showReportPublic?folderNo=ES250130-0092&org=v11...
# Processing showReportPublic?folderNo=ES250130-0093&org=v11...
# Processing showReportPublic?folderNo=ES250116-0041&org=v11...
# Processing showReportPublic?folderNo=ES241219-0057&org=v11...
# Processing showReportPublic?folderNo=ES241217-0050&org=v11...
# Processing showReportPublic?folderNo=ES241211-0080&org=v11...
# Processing showReportPublic?folderNo=ES241203-0032&org=v11...
# Processing showReportPublic?folderNo=ES241203-0034&org=v11...
# Processing showReportPublic?folderNo=ES241203-0035&org=v11...
# Processing showReportPublic?folderNo=ES241203-0031&org=v11...
# Processing showReportPublic?folderNo=ES241120-0040&org=v11...
# Processing showReportPublic?folderNo=ES241119-0039&org=v11...
# Processing showReportPublic?folderNo=ES241115-0014&org=v11...
# Processing showReportPublic?folderNo=ES241114-0074&org=v11...
# Processing showReportPublic?folderNo=ES241113-0072&org=v11...
# Processing showReportPublic?folderNo=ES241107-0099&org=v11...
# Processing showReportPublic?folderNo=ES241106-0037&org=v11...
# Processing showReportPublic?folderNo=ES241105-0122&org=v11...
# Processing showReportPublic?folderNo=ES241105-0124&org=v11...
# Processing showReportPublic?folderNo=ES241105-0125&org=v11...
# Processing showReportPublic?folderNo=ES241105-0123&org=v11...
# Processing showReportPublic?folderNo=ES241101-0017&org=v11...
# Processing showReportPublic?folderNo=ES241101-0019&org=v11...
# Processing showReportPublic?folderNo=ES241101-0018&org=v11...
# Processing showReportPublic?folderNo=ES241031-0067&org=v11...
# Processing showReportPublic?folderNo=ES241030-0046&org=v11...
# Processing showReportPublic?folderNo=ES250710-0060&org=v11...
# Processing showReportPublic?folderNo=ES250710-0059&org=v11...
# Processing showReportPublic?folderNo=ES250710-0064&org=v11...
# Processing showReportPublic?folderNo=ES250709-0062&org=v11...
# Processing showReportPublic?folderNo=ES250709-0063&org=v11...
# Processing showReportPublic?folderNo=ES250708-0044&org=v11...
# Processing showReportPublic?folderNo=ES250708-0045&org=v11...
# Processing showReportPublic?folderNo=ES250708-0043&org=v11...
# Processing showReportPublic?folderNo=ES250708-0046&org=v11...
# Processing showReportPublic?folderNo=ES250702-0055&org=v11...
# Processing showReportPublic?folderNo=ES250626-0046&org=v11...
# Processing showReportPublic?folderNo=ES250625-0050&org=v11...
# Processing showReportPublic?folderNo=ES250625-0047&org=v11...
# Processing showReportPublic?folderNo=ES250625-0051&org=v11...
# Processing showReportPublic?folderNo=ES250625-0048&org=v11...
# Processing showReportPublic?folderNo=ES250625-0049&org=v11...
# Processing showReportPublic?folderNo=ES250624-0066&org=v11...
# Processing showReportPublic?folderNo=ES250624-0067&org=v11...
# Processing showReportPublic?folderNo=ES250624-0064&org=v11...
# Processing showReportPublic?folderNo=ES250624-0065&org=v11...
# Processing showReportPublic?folderNo=ES250619-0047&org=v11...
# Processing showReportPublic?folderNo=ES250618-0074&org=v11...
# Processing showReportPublic?folderNo=ES250618-0075&org=v11...
# Processing showReportPublic?folderNo=ES250617-0053&org=v11...
# Processing showReportPublic?folderNo=ES250617-0037&org=v11...
# Processing showReportPublic?folderNo=ES250612-0052&org=v11...
# Processing showReportPublic?folderNo=ES250612-0055&org=v11...
# Processing showReportPublic?folderNo=ES250612-0053&org=v11...
# Processing showReportPublic?folderNo=ES250610-0041&org=v11...
# Processing showReportPublic?folderNo=ES250610-0042&org=v11...
# Processing showReportPublic?folderNo=ES250605-0059&org=v11...
# Processing showReportPublic?folderNo=ES250605-0058&org=v11...
# Processing showReportPublic?folderNo=ES250605-0086&org=v11...
# Processing showReportPublic?folderNo=ES250604-0062&org=v11...
# Processing showReportPublic?folderNo=ES250604-0063&org=v11...
# Processing showReportPublic?folderNo=ES250604-0064&org=v11...
# Processing showReportPublic?folderNo=ES250603-0077&org=v11...
# Processing showReportPublic?folderNo=ES250529-0060&org=v11...
# Processing showReportPublic?folderNo=ES250529-0063&org=v11...
# Processing showReportPublic?folderNo=ES250529-0068&org=v11...
# Processing showReportPublic?folderNo=ES250529-0061&org=v11...
# Processing showReportPublic?folderNo=ES250529-0064&org=v11...
# Processing showReportPublic?folderNo=ES250529-0062&org=v11...
# Processing showReportPublic?folderNo=ES250528-0044&org=v11...
# Processing showReportPublic?folderNo=ES250522-0082&org=v11...
# Processing showReportPublic?folderNo=ES250522-0076&org=v11...
# Processing showReportPublic?folderNo=ES250522-0074&org=v11...
# Processing showReportPublic?folderNo=ES250522-0078&org=v11...
# Processing showReportPublic?folderNo=ES250522-0079&org=v11...
# Processing showReportPublic?folderNo=ES250522-0075&org=v11...
# Processing showReportPublic?folderNo=ES250522-0077&org=v11...
# Processing showReportPublic?folderNo=ES250520-0048&org=v11...
# Processing showReportPublic?folderNo=ES250520-0047&org=v11...
# Processing showReportPublic?folderNo=ES250520-0050&org=v11...
# Processing showReportPublic?folderNo=ES250515-0056&org=v11...
# Processing showReportPublic?folderNo=ES250514-0064&org=v11...
# Processing showReportPublic?folderNo=ES250508-0069&org=v11...
# Processing showReportPublic?folderNo=ES250507-0053&org=v11...
# Processing showReportPublic?folderNo=ES250507-0052&org=v11...
# Processing showReportPublic?folderNo=ES250506-0037&org=v11...
# Processing showReportPublic?folderNo=ES250501-0046&org=v11...
# Processing showReportPublic?folderNo=ES250501-0043&org=v11...
# Processing showReportPublic?folderNo=ES250501-0042&org=v11...
# Processing showReportPublic?folderNo=ES250422-0069&org=v11...
# Processing showReportPublic?folderNo=ES250416-0049&org=v11...
# Processing showReportPublic?folderNo=ES250410-0037&org=v11...
# Processing showReportPublic?folderNo=ES250410-0036&org=v11...
# Processing showReportPublic?folderNo=ES250410-0038&org=v11...
# Processing showReportPublic?folderNo=ES250410-0039&org=v11...
# Processing showReportPublic?folderNo=ES250410-0040&org=v11...
# Processing showReportPublic?folderNo=ES250409-0018&org=v11...
# Processing showReportPublic?folderNo=ES250409-0015&org=v11...
# Processing showReportPublic?folderNo=ES250409-0017&org=v11...
# Processing showReportPublic?folderNo=ES250409-0016&org=v11...
# Processing showReportPublic?folderNo=ES250408-0052&org=v11...
# Processing showReportPublic?folderNo=ES250408-0053&org=v11...
# Processing showReportPublic?folderNo=ES250408-0054&org=v11...
# Processing showReportPublic?folderNo=ES250403-0036&org=v11...
# Processing showReportPublic?folderNo=ES250403-0054&org=v11...
# Processing showReportPublic?folderNo=ES250401-0046&org=v11...
# Processing showReportPublic?folderNo=ES250401-0047&org=v11...
# Processing showReportPublic?folderNo=ES250401-0062&org=v11...
# Processing showReportPublic?folderNo=ES250327-0061&org=v11...
# Processing showReportPublic?folderNo=ES250320-0045&org=v11...
# Processing showReportPublic?folderNo=ES250313-0038&org=v11...
# Processing showReportPublic?folderNo=ES250312-0041&org=v11...
# Processing showReportPublic?folderNo=ES250312-0039&org=v11...
# Processing showReportPublic?folderNo=ES250306-0059&org=v11...
# Processing showReportPublic?folderNo=ES250306-0033&org=v11...
# Processing showReportPublic?folderNo=ES250304-0035&org=v11...
# Processing showReportPublic?folderNo=ES250304-0037&org=v11...
# Processing showReportPublic?folderNo=ES250304-0036&org=v11...
# Processing showReportPublic?folderNo=ES250304-0067&org=v11...
# Processing showReportPublic?folderNo=ES250226-0051&org=v11...
# Processing showReportPublic?folderNo=ES250226-0052&org=v11...
# Processing showReportPublic?folderNo=ES250226-0053&org=v11...
# Processing showReportPublic?folderNo=ES250225-0062&org=v11...
# Processing showReportPublic?folderNo=ES250225-0054&org=v11...
# Processing showReportPublic?folderNo=ES250218-0043&org=v11...
# Processing showReportPublic?folderNo=ES250206-0049&org=v11...
# Processing showReportPublic?folderNo=ES250206-0050&org=v11...
# Processing showReportPublic?folderNo=ES250206-0051&org=v11...
# Processing showReportPublic?folderNo=ES250205-0062&org=v11...
# Processing showReportPublic?folderNo=ES250204-0044&org=v11...
# Processing showReportPublic?folderNo=ES250204-0069&org=v11...
# Processing showReportPublic?folderNo=ES250130-0097&org=v11...
# Processing showReportPublic?folderNo=ES250130-0096&org=v11...
# Processing showReportPublic?folderNo=ES250130-0098&org=v11...
# Processing showReportPublic?folderNo=ES250130-0103&org=v11...
# Processing showReportPublic?folderNo=ES250130-0095&org=v11...
# Processing showReportPublic?folderNo=ES250130-0099&org=v11...
# Processing showReportPublic?folderNo=ES250129-0052&org=v11...
# Processing showReportPublic?folderNo=ES250129-0051&org=v11...
# Processing showReportPublic?folderNo=ES250128-0049&org=v11...
# Processing showReportPublic?folderNo=ES250128-0047&org=v11...
# Processing showReportPublic?folderNo=ES250128-0048&org=v11...
# Processing showReportPublic?folderNo=ES250116-0038&org=v11...
# Processing showReportPublic?folderNo=ES250116-0039&org=v11...
# Processing showReportPublic?folderNo=ES250116-0048&org=v11...
# Processing showReportPublic?folderNo=ES250115-0096&org=v11...
# Processing showReportPublic?folderNo=ES250109-0073&org=v11...
# Processing showReportPublic?folderNo=ES241219-0053&org=v11...
# Processing showReportPublic?folderNo=ES241219-0059&org=v11...
# Processing showReportPublic?folderNo=ES241219-0060&org=v11...
# Processing showReportPublic?folderNo=ES241219-0058&org=v11...
# Processing showReportPublic?folderNo=ES241219-0052&org=v11...
# Processing showReportPublic?folderNo=ES241218-0038&org=v11...
# Processing showReportPublic?folderNo=ES241218-0037&org=v11...
# Processing showReportPublic?folderNo=ES241218-0040&org=v11...
# Processing showReportPublic?folderNo=ES241218-0039&org=v11...
# Processing showReportPublic?folderNo=ES241217-0053&org=v11...
# Processing showReportPublic?folderNo=ES241217-0054&org=v11...
# Processing showReportPublic?folderNo=ES241217-0051&org=v11...
# Processing showReportPublic?folderNo=ES241217-0091&org=v11...
# Processing showReportPublic?folderNo=ES241217-0052&org=v11...
# Processing showReportPublic?folderNo=ES241212-0028&org=v11...
# Processing showReportPublic?folderNo=ES241211-0046&org=v11...
# Processing showReportPublic?folderNo=ES241211-0078&org=v11...
# Processing showReportPublic?folderNo=ES241211-0043&org=v11...
# Processing showReportPublic?folderNo=ES241211-0044&org=v11...
# Processing showReportPublic?folderNo=ES241211-0045&org=v11...
# Processing showReportPublic?folderNo=ES241211-0079&org=v11...
# Processing showReportPublic?folderNo=ES241211-0056&org=v11...
# Processing showReportPublic?folderNo=ES241210-0072&org=v11...
# Processing showReportPublic?folderNo=ES241210-0073&org=v11...
# Processing showReportPublic?folderNo=ES241210-0074&org=v11...
# Processing showReportPublic?folderNo=ES241210-0081&org=v11...
# Processing showReportPublic?folderNo=ES241205-0040&org=v11...
# Processing showReportPublic?folderNo=ES241205-0043&org=v11...
# Processing showReportPublic?folderNo=ES241204-0031&org=v11...
# Processing showReportPublic?folderNo=ES241204-0030&org=v11...
# Processing showReportPublic?folderNo=ES241127-0030&org=v11...
# Processing showReportPublic?folderNo=ES241127-0069&org=v11...
# Processing showReportPublic?folderNo=ES241127-0031&org=v11...
# Processing showReportPublic?folderNo=ES241127-0034&org=v11...
# Processing showReportPublic?folderNo=ES241127-0033&org=v11...
# Processing showReportPublic?folderNo=ES241127-0035&org=v11...
# Processing showReportPublic?folderNo=ES241127-0032&org=v11...
# Processing showReportPublic?folderNo=ES241126-0063&org=v11...
# Processing showReportPublic?folderNo=ES241126-0104&org=v11...
# Processing showReportPublic?folderNo=ES241126-0065&org=v11...
# Processing showReportPublic?folderNo=ES241126-0064&org=v11...
# Processing showReportPublic?folderNo=ES241126-0061&org=v11...
# Processing showReportPublic?folderNo=ES241126-0062&org=v11...
# Processing showReportPublic?folderNo=ES241126-0060&org=v11...
# Processing showReportPublic?folderNo=ES241122-0022&org=v11...
# Processing showReportPublic?folderNo=ES241121-0087&org=v11...
# Processing showReportPublic?folderNo=ES241121-0090&org=v11...
# Processing showReportPublic?folderNo=ES241121-0088&org=v11...
# Processing showReportPublic?folderNo=ES241121-0089&org=v11...
# Processing showReportPublic?folderNo=ES241121-0086&org=v11...
# Processing showReportPublic?folderNo=ES241120-0041&org=v11...
# Processing showReportPublic?folderNo=ES241120-0068&org=v11...
# Processing showReportPublic?folderNo=ES241120-0044&org=v11...
# Processing showReportPublic?folderNo=ES241120-0045&org=v11...
# Processing showReportPublic?folderNo=ES241120-0042&org=v11...
# Processing showReportPublic?folderNo=ES241120-0043&org=v11...
# Processing showReportPublic?folderNo=ES241120-0046&org=v11...
# Processing showReportPublic?folderNo=ES241120-0047&org=v11...
# Processing showReportPublic?folderNo=ES241120-0048&org=v11...
# Processing showReportPublic?folderNo=ES241119-0040&org=v11...
# Processing showReportPublic?folderNo=ES241119-0041&org=v11...
# Processing showReportPublic?folderNo=ES241116-0003&org=v11...
# Processing showReportPublic?folderNo=ES241116-0001&org=v11...
# Processing showReportPublic?folderNo=ES241116-0004&org=v11...
# Processing showReportPublic?folderNo=ES241116-0002&org=v11...
# Processing showReportPublic?folderNo=ES241114-0068&org=v11...
# Processing showReportPublic?folderNo=ES241114-0067&org=v11...
# Processing showReportPublic?folderNo=ES241114-0099&org=v11...
# Processing showReportPublic?folderNo=ES241108-0013&org=v11...
# Processing showReportPublic?folderNo=ES241108-0014&org=v11...
# Processing showReportPublic?folderNo=ES241108-0012&org=v11...
# Processing showReportPublic?folderNo=ES241105-0127&org=v11...
# Processing showReportPublic?folderNo=ES241105-0126&org=v11...
# Processing showReportPublic?folderNo=ES241105-0069&org=v11...
# Processing showReportPublic?folderNo=ES241102-0001&org=v11...
# Processing showReportPublic?folderNo=ES241102-0002&org=v11...
# Processing showReportPublic?folderNo=ES241102-0003&org=v11...
# Processing showReportPublic?folderNo=ES241102-0004&org=v11...
# Processing showReportPublic?folderNo=ES241030-0045&org=v11...
# Processing showReportPublic?folderNo=ES241112-0037&org=v11...
# Processing showReportPublic?folderNo=ES241026-0002&org=v11...
# Processing showReportPublic?folderNo=ES241026-0001&org=v11...
# Processing showReportPublic?folderNo=ES241026-0003&org=v11...
# Processing showReportPublic?folderNo=ES241025-0015&org=v11...
# Processing showReportPublic?folderNo=ES241025-0014&org=v11...
# Processing showReportPublic?folderNo=ES241024-0052&org=v11...
# Processing showReportPublic?folderNo=ES241024-0053&org=v11...
# Processing showReportPublic?folderNo=ES241024-0051&org=v11...
# Processing showReportPublic?folderNo=ES241023-0071&org=v11...
# Processing showReportPublic?folderNo=ES241023-0081&org=v11...
# Processing showReportPublic?folderNo=ES241023-0072&org=v11...
# Processing showReportPublic?folderNo=ES241023-0073&org=v11...
# Processing showReportPublic?folderNo=ES241022-0081&org=v11...
# Processing showReportPublic?folderNo=ES241019-0005&org=v11...
# Processing showReportPublic?folderNo=ES241019-0004&org=v11...
# Processing showReportPublic?folderNo=ES241019-0003&org=v11...
# Processing showReportPublic?folderNo=ES241019-0006&org=v11...
# Processing showReportPublic?folderNo=ES241019-0001&org=v11...
# Processing showReportPublic?folderNo=ES241019-0002&org=v11...
# Processing showReportPublic?folderNo=ES241018-0007&org=v11...
# Processing showReportPublic?folderNo=ES241017-0031&org=v11...
# Processing showReportPublic?folderNo=ES241017-0030&org=v11...
# Processing showReportPublic?folderNo=ES241101-0040&org=v11...
# Processing showReportPublic?folderNo=ES250319-0045&org=v11...
# Processing showReportPublic?folderNo=ES250311-0040&org=v11...
# Processing showReportPublic?folderNo=ES250219-0114&org=v11...
# Processing showReportPublic?folderNo=ES250130-0100&org=v11...
# Processing showReportPublic?folderNo=ES241219-0054&org=v11...
# Processing showReportPublic?folderNo=ES241219-0061&org=v11...
# Processing showReportPublic?folderNo=ES241203-0036&org=v11...
# Processing showReportPublic?folderNo=ES241126-0066&org=v11...
# Processing showReportPublic?folderNo=ES241121-0091&org=v11...
# Processing showReportPublic?folderNo=ES241121-0092&org=v11...
# Processing showReportPublic?folderNo=ES241119-0042&org=v11...
# Processing showReportPublic?folderNo=ES241119-0043&org=v11...
# Processing showReportPublic?folderNo=ES241116-0006&org=v11...
# Processing showReportPublic?folderNo=ES241113-0073&org=v11...
# Processing showReportPublic?folderNo=ES241108-0043&org=v11...
# Processing showReportPublic?folderNo=ES241106-0038&org=v11...
# Processing showReportPublic?folderNo=ES241031-0079&org=v11...
# Processing showReportPublic?folderNo=ES241030-0047&org=v11...
# Processing showReportPublic?folderNo=ES241029-0063&org=v11...
# Processing showReportPublic?folderNo=ES241025-0016&org=v11...
# Processing showReportPublic?folderNo=ES241025-0017&org=v11...
# Processing showReportPublic?folderNo=ES250619-0038&org=v11...
# Processing showReportPublic?folderNo=ES250603-0078&org=v11...
# Processing showReportPublic?folderNo=ES250603-0079&org=v11...
# Processing showReportPublic?folderNo=ES250522-0081&org=v11...
# Processing showReportPublic?folderNo=ES250522-0080&org=v11...
# Processing showReportPublic?folderNo=ES250521-0050&org=v11...
# Processing showReportPublic?folderNo=ES250501-0045&org=v11...
# Processing showReportPublic?folderNo=ES250501-0044&org=v11...
# Processing showReportPublic?folderNo=ES250430-0060&org=v11...
# Processing showReportPublic?folderNo=ES250415-0054&org=v11...
# Processing showReportPublic?folderNo=ES250401-0048&org=v11...
# Processing showReportPublic?folderNo=ES250327-0062&org=v11...
# Processing showReportPublic?folderNo=ES250318-0035&org=v11...
# Processing showReportPublic?folderNo=ES250311-0041&org=v11...
# Processing showReportPublic?folderNo=ES250304-0038&org=v11...
# Processing showReportPublic?folderNo=ES250219-0115&org=v11...
# Processing showReportPublic?folderNo=ES250205-0063&org=v11...
# Processing showReportPublic?folderNo=ES250130-0101&org=v11...
# Processing showReportPublic?folderNo=ES250128-0051&org=v11...
# Processing showReportPublic?folderNo=ES250128-0050&org=v11...
# Processing showReportPublic?folderNo=ES250122-0028&org=v11...
# Processing showReportPublic?folderNo=ES250116-0044&org=v11...
# Processing showReportPublic?folderNo=ES250116-0043&org=v11...
# Processing showReportPublic?folderNo=ES250116-0042&org=v11...
# Processing showReportPublic?folderNo=ES250115-0087&org=v11...
# Processing showReportPublic?folderNo=ES250109-0074&org=v11...
# Processing showReportPublic?folderNo=ES250108-0061&org=v11...
# Warning: City, state, or zip not found for ES250108-0061
# Processing showReportPublic?folderNo=ES250107-0041&org=v11...
# Processing showReportPublic?folderNo=ES250107-0043&org=v11...
# Processing showReportPublic?folderNo=ES250107-0040&org=v11...
# Processing showReportPublic?folderNo=ES250107-0042&org=v11...
# Processing showReportPublic?folderNo=ES241218-0041&org=v11...
# Processing showReportPublic?folderNo=ES241217-0055&org=v11...
# Processing showReportPublic?folderNo=ES241211-0047&org=v11...
# Processing showReportPublic?folderNo=ES241207-0001&org=v11...
# Processing showReportPublic?folderNo=ES241206-0011&org=v11...
# Processing showReportPublic?folderNo=ES241205-0044&org=v11...
# Processing showReportPublic?folderNo=ES241205-0046&org=v11...
# Processing showReportPublic?folderNo=ES241205-0047&org=v11...
# Processing showReportPublic?folderNo=ES241205-0045&org=v11...
# Processing showReportPublic?folderNo=ES241204-0032&org=v11...
# Processing showReportPublic?folderNo=ES241127-0036&org=v11...
# Processing showReportPublic?folderNo=ES241126-0067&org=v11...
# Processing showReportPublic?folderNo=ES241123-0001&org=v11...
# Processing showReportPublic?folderNo=ES241121-0095&org=v11...
# Processing showReportPublic?folderNo=ES241121-0096&org=v11...
# Processing showReportPublic?folderNo=ES241121-0097&org=v11...
# Processing showReportPublic?folderNo=ES241121-0094&org=v11...
# Processing showReportPublic?folderNo=ES241121-0093&org=v11...
# Processing showReportPublic?folderNo=ES241120-0049&org=v11...
# Processing showReportPublic?folderNo=ES241120-0050&org=v11...
# Processing showReportPublic?folderNo=ES241119-0074&org=v11...
# Processing showReportPublic?folderNo=ES241119-0045&org=v11...
# Processing showReportPublic?folderNo=ES241119-0044&org=v11...
# Processing showReportPublic?folderNo=ES241116-0005&org=v11...
# Processing showReportPublic?folderNo=ES241115-0015&org=v11...
# Processing showReportPublic?folderNo=ES241114-0071&org=v11...
# Processing showReportPublic?folderNo=ES241114-0070&org=v11...
# Processing showReportPublic?folderNo=ES241114-0069&org=v11...
# Processing showReportPublic?folderNo=ES241113-0075&org=v11...
# Processing showReportPublic?folderNo=ES241113-0079&org=v11...
# Processing showReportPublic?folderNo=ES241113-0074&org=v11...
# Processing showReportPublic?folderNo=ES241113-0076&org=v11...
# Processing showReportPublic?folderNo=ES241109-0001&org=v11...
# Processing showReportPublic?folderNo=ES241109-0002&org=v11...
# Processing showReportPublic?folderNo=ES241108-0047&org=v11...
# Processing showReportPublic?folderNo=ES241108-0044&org=v11...
# Processing showReportPublic?folderNo=ES241108-0048&org=v11...
# Processing showReportPublic?folderNo=ES241108-0045&org=v11...
# Processing showReportPublic?folderNo=ES241108-0046&org=v11...
# Processing showReportPublic?folderNo=ES241107-0101&org=v11...
# Processing showReportPublic?folderNo=ES241107-0102&org=v11...
# Processing showReportPublic?folderNo=ES241107-0100&org=v11...
# Processing showReportPublic?folderNo=ES241106-0039&org=v11...
# Processing showReportPublic?folderNo=ES241105-0128&org=v11...
# Processing showReportPublic?folderNo=ES241105-0129&org=v11...
# Processing showReportPublic?folderNo=ES241105-0130&org=v11...
# Processing showReportPublic?folderNo=ES241102-0006&org=v11...
# Processing showReportPublic?folderNo=ES241102-0008&org=v11...
# Processing showReportPublic?folderNo=ES241102-0007&org=v11...
# Processing showReportPublic?folderNo=ES241102-0005&org=v11...
# Processing showReportPublic?folderNo=ES241101-0020&org=v11...
# Processing showReportPublic?folderNo=ES241101-0022&org=v11...
# Processing showReportPublic?folderNo=ES241101-0023&org=v11...
# Processing showReportPublic?folderNo=ES241101-0021&org=v11...
# Processing showReportPublic?folderNo=ES241101-0024&org=v11...
# Processing showReportPublic?folderNo=ES241031-0068&org=v11...
# Processing showReportPublic?folderNo=ES241031-0073&org=v11...
# Processing showReportPublic?folderNo=ES241031-0069&org=v11...
# Processing showReportPublic?folderNo=ES241031-0070&org=v11...
# Processing showReportPublic?folderNo=ES241031-0074&org=v11...
# Processing showReportPublic?folderNo=ES241031-0072&org=v11...
# Processing showReportPublic?folderNo=ES241031-0081&org=v11...
# Processing showReportPublic?folderNo=ES241030-0051&org=v11...
# Processing showReportPublic?folderNo=ES241030-0049&org=v11...
# Processing showReportPublic?folderNo=ES241031-0071&org=v11...
# Processing showReportPublic?folderNo=ES241030-0050&org=v11...
# Processing showReportPublic?folderNo=ES241030-0053&org=v11...
# Processing showReportPublic?folderNo=ES241030-0052&org=v11...
# Processing showReportPublic?folderNo=ES241030-0048&org=v11...
# Processing showReportPublic?folderNo=ES241029-0065&org=v11...
# Processing showReportPublic?folderNo=ES241029-0066&org=v11...
# Processing showReportPublic?folderNo=ES241029-0064&org=v11...
# Processing showReportPublic?folderNo=ES241026-0004&org=v11...
# Processing showReportPublic?folderNo=ES241026-0005&org=v11...
# Processing showReportPublic?folderNo=ES241025-0020&org=v11...
# Processing showReportPublic?folderNo=ES241025-0019&org=v11...
# Processing showReportPublic?folderNo=ES241025-0018&org=v11...
# Processing showReportPublic?folderNo=ES241024-0054&org=v11...
# Processing showReportPublic?folderNo=ES241024-0055&org=v11...
# Processing showReportPublic?folderNo=ES241024-0057&org=v11...
# Processing showReportPublic?folderNo=ES241024-0056&org=v11...
# Processing showReportPublic?folderNo=ES241024-0059&org=v11...
# Processing showReportPublic?folderNo=ES241023-0074&org=v11...
# Processing showReportPublic?folderNo=ES241022-0083&org=v11...
# Processing showReportPublic?folderNo=ES241022-0082&org=v11...
# Processing showReportPublic?folderNo=ES241019-0008&org=v11...
# Processing showReportPublic?folderNo=ES241019-0007&org=v11...
# Processing showReportPublic?folderNo=ES241018-0008&org=v11...
# Processing showReportPublic?folderNo=ES241017-0035&org=v11...
# Processing showReportPublic?folderNo=ES241017-0036&org=v11...
# Processing showReportPublic?folderNo=ES241016-0055&org=v11...
# Processing showReportPublic?folderNo=ES241016-0056&org=v11...
# Processing showReportPublic?folderNo=ES241016-0053&org=v11...
# Processing showReportPublic?folderNo=ES241016-0054&org=v11...
# Processing showReportPublic?folderNo=ES241010-0089&org=v11...
# Processing showReportPublic?folderNo=ES241010-0090&org=v11...
# Processing showReportPublic?folderNo=ES241119-0046&org=v11...
# Processing showReportPublic?folderNo=ES241031-0080&org=v11...
# Processing showReportPublic?folderNo=ES241018-0009&org=v11...
# Processing showReportPublic?folderNo=ES241022-0084&org=v11...
# Processing showReportPublic?folderNo=ES250625-0052&org=v11...
# Processing showReportPublic?folderNo=ES250520-0049&org=v11...
# Processing showReportPublic?folderNo=ES250514-0079&org=v11...
# Processing showReportPublic?folderNo=ES250327-0064&org=v11...
# Processing showReportPublic?folderNo=ES250327-0063&org=v11...
# Processing showReportPublic?folderNo=ES250320-0044&org=v11...
# Processing showReportPublic?folderNo=ES250219-0116&org=v11...
# Processing showReportPublic?folderNo=ES250115-0086&org=v11...
# Processing showReportPublic?folderNo=ES250107-0044&org=v11...
# Processing showReportPublic?folderNo=ES241212-0029&org=v11...
# Processing showReportPublic?folderNo=ES241203-0037&org=v11...
# Processing showReportPublic?folderNo=ES241203-0038&org=v11...
# Processing showReportPublic?folderNo=ES241127-0037&org=v11...
# Processing showReportPublic?folderNo=ES241126-0068&org=v11...
# Processing showReportPublic?folderNo=ES241126-0069&org=v11...
# Processing showReportPublic?folderNo=ES241126-0070&org=v11...
# Processing showReportPublic?folderNo=ES241120-0051&org=v11...
# Processing showReportPublic?folderNo=ES241114-0072&org=v11...
# Processing showReportPublic?folderNo=ES241113-0077&org=v11...
# Processing showReportPublic?folderNo=ES241107-0042&org=v11...
# Processing showReportPublic?folderNo=ES241107-0103&org=v11...
# Processing showReportPublic?folderNo=ES241107-0041&org=v11...
# Processing showReportPublic?folderNo=ES241106-0040&org=v11...
# Processing showReportPublic?folderNo=ES241106-0041&org=v11...
# Processing showReportPublic?folderNo=ES241105-0070&org=v11...
# Processing showReportPublic?folderNo=ES241031-0075&org=v11...
# Processing showReportPublic?folderNo=ES241031-0082&org=v11...
# Processing showReportPublic?folderNo=ES241030-0054&org=v11...
# Processing showReportPublic?folderNo=ES241029-0067&org=v11...
# Processing showReportPublic?folderNo=ES241029-0068&org=v11...
# Processing showReportPublic?folderNo=ES241029-0071&org=v11...
# Processing showReportPublic?folderNo=ES241029-0070&org=v11...
# Processing showReportPublic?folderNo=ES241029-0069&org=v11...
# Processing showReportPublic?folderNo=ES241023-0076&org=v11...
# Processing showReportPublic?folderNo=ES241023-0075&org=v11...
# Processing showReportPublic?folderNo=ES241022-0085&org=v11...
# Processing showReportPublic?folderNo=ES241022-0086&org=v11...
# Processing showReportPublic?folderNo=ES241017-0038&org=v11...
# Processing showReportPublic?folderNo=ES241017-0037&org=v11...
# Processing showReportPublic?folderNo=ES241015-0039&org=v11...
# Processing showReportPublic?folderNo=ES241015-0040&org=v11...
# Processing showReportPublic?folderNo=ES241010-0091&org=v11...
# Processing showReportPublic?folderNo=ES241010-0092&org=v11...
# Processing showReportPublic?folderNo=ES241010-0093&org=v11...
# Processing showReportPublic?folderNo=ES250114-0045&org=v11...
# Processing showReportPublic?folderNo=ES241031-0149&org=v11...
# Processing showReportPublic?folderNo=ES241031-0150&org=v11...
# Processing showReportPublic?folderNo=ES241119-0071&org=v11...
# Processing showReportPublic?folderNo=ES241107-0043&org=v11...
# Processing showReportPublic?folderNo=ES241203-0105&org=v11...
# Processing showReportPublic?folderNo=ES241025-0025&org=v11...
# Processing showReportPublic?folderNo=ES250429-0066&org=v11...
# Processing showReportPublic?folderNo=ES250109-0075&org=v11...
# Processing showReportPublic?folderNo=ES250108-0092&org=v11...
# Processing showReportPublic?folderNo=ES250108-0062&org=v11...
# Processing showReportPublic?folderNo=ES241211-0048&org=v11...
# Processing showReportPublic?folderNo=ES241210-0076&org=v11...
# Processing showReportPublic?folderNo=ES241203-0039&org=v11...
# Processing showReportPublic?folderNo=ES241126-0071&org=v11...
# Processing showReportPublic?folderNo=ES241121-0098&org=v11...
# Processing showReportPublic?folderNo=ES241113-0078&org=v11...
# Processing showReportPublic?folderNo=ES241107-0044&org=v11...
# Processing showReportPublic?folderNo=ES241106-0042&org=v11...
# Warning: City, state, or zip not found for ES241106-0042
# Processing showReportPublic?folderNo=ES241106-0044&org=v11...
# Processing showReportPublic?folderNo=ES241106-0043&org=v11...
# Processing showReportPublic?folderNo=ES241105-0066&org=v11...
# Processing showReportPublic?folderNo=ES241105-0067&org=v11...
# Processing showReportPublic?folderNo=ES241105-0068&org=v11...
# Processing showReportPublic?folderNo=ES241031-0077&org=v11...
# Processing showReportPublic?folderNo=ES241031-0076&org=v11...
# Processing showReportPublic?folderNo=ES241031-0078&org=v11...
# Processing showReportPublic?folderNo=ES241030-0056&org=v11...
# Processing showReportPublic?folderNo=ES241030-0055&org=v11...
# Processing showReportPublic?folderNo=ES241024-0060&org=v11...
# Processing showReportPublic?folderNo=ES241023-0077&org=v11...
# Processing showReportPublic?folderNo=ES241022-0087&org=v11...
# Processing showReportPublic?folderNo=ES241022-0090&org=v11...
# Processing showReportPublic?folderNo=ES241022-0088&org=v11...
# Processing showReportPublic?folderNo=ES241022-0089&org=v11...
# Processing showReportPublic?folderNo=ES241022-0091&org=v11...
# Processing showReportPublic?folderNo=ES241022-0092&org=v11...
# Processing showReportPublic?folderNo=ES241017-0041&org=v11...
# Processing showReportPublic?folderNo=ES241017-0042&org=v11...
# Processing showReportPublic?folderNo=ES241017-0040&org=v11...
# Processing showReportPublic?folderNo=ES241017-0039&org=v11...
# Processing showReportPublic?folderNo=ES241017-0032&org=v11...
# Processing showReportPublic?folderNo=ES241016-0062&org=v11...
# Processing showReportPublic?folderNo=ES241016-0061&org=v11...
# Processing showReportPublic?folderNo=ES241017-0034&org=v11...
# Processing showReportPublic?folderNo=ES241016-0081&org=v11...
# Processing showReportPublic?folderNo=ES241016-0088&org=v11...
# Processing showReportPublic?folderNo=ES241016-0059&org=v11...
# Processing showReportPublic?folderNo=ES241016-0060&org=v11...
# Processing showReportPublic?folderNo=ES241017-0033&org=v11...
# Processing showReportPublic?folderNo=ES241016-0087&org=v11...
# Processing showReportPublic?folderNo=ES241015-0041&org=v11...
# Processing showReportPublic?folderNo=ES241015-0043&org=v11...
# Processing showReportPublic?folderNo=ES241015-0046&org=v11...
# Processing showReportPublic?folderNo=ES241015-0047&org=v11...
# Processing showReportPublic?folderNo=ES241015-0048&org=v11...
# Processing showReportPublic?folderNo=ES241016-0064&org=v11...
# Processing showReportPublic?folderNo=ES241016-0057&org=v11...
# Processing showReportPublic?folderNo=ES241015-0042&org=v11...
# Processing showReportPublic?folderNo=ES241016-0063&org=v11...
# Processing showReportPublic?folderNo=ES241015-0045&org=v11...
# Processing showReportPublic?folderNo=ES241015-0044&org=v11...
# Processing showReportPublic?folderNo=ES241010-0094&org=v11...
# Processing showReportPublic?folderNo=ES241010-0095&org=v11...
# Processing showReportPublic?folderNo=ES241010-0096&org=v11...
# Processing showReportPublic?folderNo=ES241010-0097&org=v11...
# Processing showReportPublic?folderNo=ES241010-0098&org=v11...
# Processing showReportPublic?folderNo=ES241212-0078&org=v11...
# Processing showReportPublic?folderNo=ES241211-0133&org=v11...
# Processing showReportPublic?folderNo=ES241116-0007&org=v11...
# Processing showReportPublic?folderNo=ES250206-0052&org=v11...
# Processing showReportPublic?folderNo=ES250116-0045&org=v11...
# Processing showReportPublic?folderNo=ES250115-0088&org=v11...
# Processing showReportPublic?folderNo=ES241119-0047&org=v11...
# Processing showReportPublic?folderNo=ES241022-0093&org=v11...
# Processing showReportPublic?folderNo=ES241016-0058&org=v11...
# Processing showReportPublic?folderNo=ES250710-0062&org=v11...
# Processing showReportPublic?folderNo=ES250710-0061&org=v11...
# Processing showReportPublic?folderNo=ES250710-0063&org=v11...
# Processing showReportPublic?folderNo=ES250702-0056&org=v11...
# Processing showReportPublic?folderNo=ES250626-0045&org=v11...
# Processing showReportPublic?folderNo=ES250619-0039&org=v11...
# Processing showReportPublic?folderNo=ES250612-0056&org=v11...
# Processing showReportPublic?folderNo=ES250605-0062&org=v11...
# Processing showReportPublic?folderNo=ES250603-0080&org=v11...
# Processing showReportPublic?folderNo=ES250529-0065&org=v11...
# Processing showReportPublic?folderNo=ES250515-0057&org=v11...
# Processing showReportPublic?folderNo=ES250514-0080&org=v11...
# Processing showReportPublic?folderNo=ES250429-0067&org=v11...
# Processing showReportPublic?folderNo=ES250424-0051&org=v11...
# Processing showReportPublic?folderNo=ES250423-0044&org=v11...
# Processing showReportPublic?folderNo=ES250423-0043&org=v11...
# Processing showReportPublic?folderNo=ES250410-0041&org=v11...
# Processing showReportPublic?folderNo=ES250409-0019&org=v11...
# Processing showReportPublic?folderNo=ES250327-0065&org=v11...
# Processing showReportPublic?folderNo=ES250325-0049&org=v11...
# Processing showReportPublic?folderNo=ES250325-0050&org=v11...
# Processing showReportPublic?folderNo=ES250325-0048&org=v11...
# Processing showReportPublic?folderNo=ES250320-0043&org=v11...
# Processing showReportPublic?folderNo=ES250312-0040&org=v11...
# Processing showReportPublic?folderNo=ES250311-0043&org=v11...
# Processing showReportPublic?folderNo=ES250311-0042&org=v11...
# Processing showReportPublic?folderNo=ES250306-0034&org=v11...
# Processing showReportPublic?folderNo=ES250306-0035&org=v11...
# Processing showReportPublic?folderNo=ES250306-0036&org=v11...
# Processing showReportPublic?folderNo=ES250304-0039&org=v11...
# Processing showReportPublic?folderNo=ES250227-0027&org=v11...
# Processing showReportPublic?folderNo=ES250227-0026&org=v11...
# Processing showReportPublic?folderNo=ES250227-0028&org=v11...
# Processing showReportPublic?folderNo=ES250226-0054&org=v11...
# Processing showReportPublic?folderNo=ES250226-0055&org=v11...
# Processing showReportPublic?folderNo=ES250225-0055&org=v11...
# Processing showReportPublic?folderNo=ES250225-0057&org=v11...
# Processing showReportPublic?folderNo=ES250225-0056&org=v11...
# Processing showReportPublic?folderNo=ES250219-0117&org=v11...
# Processing showReportPublic?folderNo=ES250213-0030&org=v11...
# Processing showReportPublic?folderNo=ES250211-0045&org=v11...
# Processing showReportPublic?folderNo=ES250211-0046&org=v11...
# Processing showReportPublic?folderNo=ES250206-0054&org=v11...
# Processing showReportPublic?folderNo=ES250206-0053&org=v11...
# Processing showReportPublic?folderNo=ES250205-0066&org=v11...
# Processing showReportPublic?folderNo=ES250205-0065&org=v11...
# Processing showReportPublic?folderNo=ES250205-0064&org=v11...
# Processing showReportPublic?folderNo=ES250204-0045&org=v11...
# Processing showReportPublic?folderNo=ES250204-0046&org=v11...
# Processing showReportPublic?folderNo=ES250130-0102&org=v11...
# Processing showReportPublic?folderNo=ES250129-0053&org=v11...
# Processing showReportPublic?folderNo=ES250116-0040&org=v11...
# Processing showReportPublic?folderNo=ES250116-0046&org=v11...
# Processing showReportPublic?folderNo=ES250116-0047&org=v11...
# Processing showReportPublic?folderNo=ES250115-0089&org=v11...
# Processing showReportPublic?folderNo=ES250114-0049&org=v11...
# Processing showReportPublic?folderNo=ES250114-0046&org=v11...
# Processing showReportPublic?folderNo=ES250114-0047&org=v11...
# Processing showReportPublic?folderNo=ES250114-0048&org=v11...
# Processing showReportPublic?folderNo=ES250109-0072&org=v11...
# Processing showReportPublic?folderNo=ES250109-0216&org=v11...
# Processing showReportPublic?folderNo=ES250109-0217&org=v11...
# Processing showReportPublic?folderNo=ES250108-0064&org=v11...
# Processing showReportPublic?folderNo=ES250108-0063&org=v11...
# Processing showReportPublic?folderNo=ES250107-0045&org=v11...
# Processing showReportPublic?folderNo=ES241219-0062&org=v11...
# Processing showReportPublic?folderNo=ES241219-0065&org=v11...
# Processing showReportPublic?folderNo=ES241219-0064&org=v11...
# Processing showReportPublic?folderNo=ES241219-0066&org=v11...
# Processing showReportPublic?folderNo=ES241219-0055&org=v11...
# Processing showReportPublic?folderNo=ES241219-0063&org=v11...
# Processing showReportPublic?folderNo=ES241219-0067&org=v11...
# Processing showReportPublic?folderNo=ES241219-0056&org=v11...
# Processing showReportPublic?folderNo=ES241219-0068&org=v11...
# Processing showReportPublic?folderNo=ES241218-0042&org=v11...
# Processing showReportPublic?folderNo=ES241218-0044&org=v11...
# Processing showReportPublic?folderNo=ES241218-0036&org=v11...
# Processing showReportPublic?folderNo=ES241218-0043&org=v11...
# Processing showReportPublic?folderNo=ES241217-0059&org=v11...
# Processing showReportPublic?folderNo=ES241217-0064&org=v11...
# Processing showReportPublic?folderNo=ES241217-0062&org=v11...
# Processing showReportPublic?folderNo=ES241217-0058&org=v11...
# Processing showReportPublic?folderNo=ES241217-0061&org=v11...
# Processing showReportPublic?folderNo=ES241217-0056&org=v11...
# Processing showReportPublic?folderNo=ES241217-0060&org=v11...
# Processing showReportPublic?folderNo=ES241217-0063&org=v11...
# Processing showReportPublic?folderNo=ES241217-0057&org=v11...
# Processing showReportPublic?folderNo=ES241212-0031&org=v11...
# Processing showReportPublic?folderNo=ES241212-0030&org=v11...
# Processing showReportPublic?folderNo=ES241212-0033&org=v11...
# Processing showReportPublic?folderNo=ES241212-0032&org=v11...
# Processing showReportPublic?folderNo=ES241211-0054&org=v11...
# Processing showReportPublic?folderNo=ES241212-0034&org=v11...
# Processing showReportPublic?folderNo=ES241211-0053&org=v11...
# Processing showReportPublic?folderNo=ES241211-0050&org=v11...
# Processing showReportPublic?folderNo=ES241211-0051&org=v11...
# Processing showReportPublic?folderNo=ES241211-0052&org=v11...
# Processing showReportPublic?folderNo=ES241211-0055&org=v11...
# Processing showReportPublic?folderNo=ES241211-0049&org=v11...
# Processing showReportPublic?folderNo=ES241210-0080&org=v11...
# Processing showReportPublic?folderNo=ES241210-0078&org=v11...
# Processing showReportPublic?folderNo=ES241210-0075&org=v11...
# Processing showReportPublic?folderNo=ES241210-0079&org=v11...
# Processing showReportPublic?folderNo=ES241210-0077&org=v11...
# Processing showReportPublic?folderNo=ES241207-0002&org=v11...
# Processing showReportPublic?folderNo=ES241205-0050&org=v11...
# Processing showReportPublic?folderNo=ES241205-0041&org=v11...
# Processing showReportPublic?folderNo=ES241205-0051&org=v11...
# Processing showReportPublic?folderNo=ES241205-0052&org=v11...
# Processing showReportPublic?folderNo=ES241205-0049&org=v11...
# Processing showReportPublic?folderNo=ES241205-0053&org=v11...
# Processing showReportPublic?folderNo=ES241205-0048&org=v11...
# Processing showReportPublic?folderNo=ES241205-0042&org=v11...
# Processing showReportPublic?folderNo=ES241205-0054&org=v11...
# Processing showReportPublic?folderNo=ES241204-0034&org=v11...
# Processing showReportPublic?folderNo=ES241205-0055&org=v11...
# Processing showReportPublic?folderNo=ES241204-0036&org=v11...
# Processing showReportPublic?folderNo=ES241204-0033&org=v11...
# Processing showReportPublic?folderNo=ES241204-0038&org=v11...
# Processing showReportPublic?folderNo=ES241204-0039&org=v11...
# Processing showReportPublic?folderNo=ES241204-0035&org=v11...
# Processing showReportPublic?folderNo=ES241204-0037&org=v11...
# Processing showReportPublic?folderNo=ES241203-0040&org=v11...
# Processing showReportPublic?folderNo=ES241203-0041&org=v11...
# Processing showReportPublic?folderNo=ES241127-0043&org=v11...
# Processing showReportPublic?folderNo=ES241127-0039&org=v11...
# Processing showReportPublic?folderNo=ES241127-0044&org=v11...
# Processing showReportPublic?folderNo=ES241127-0038&org=v11...
# Processing showReportPublic?folderNo=ES241127-0040&org=v11...
# Processing showReportPublic?folderNo=ES241127-0042&org=v11...
# Processing showReportPublic?folderNo=ES241127-0041&org=v11...
# Processing showReportPublic?folderNo=ES241126-0076&org=v11...
# Processing showReportPublic?folderNo=ES241126-0074&org=v11...
# Processing showReportPublic?folderNo=ES241126-0075&org=v11...
# Processing showReportPublic?folderNo=ES241126-0073&org=v11...
# Processing showReportPublic?folderNo=ES241126-0072&org=v11...
# Processing showReportPublic?folderNo=ES241106-0047&org=v11...
# Processing showReportPublic?folderNo=ES241019-0013&org=v11...
# Processing showReportPublic?folderNo=ES241019-0011&org=v11...
# Processing showReportPublic?folderNo=ES241019-0012&org=v11...
# Processing showReportPublic?folderNo=ES241019-0009&org=v11...
# Processing showReportPublic?folderNo=ES241019-0010&org=v11...
# Processing showReportPublic?folderNo=ES241019-0014&org=v11...
# Processing showReportPublic?folderNo=ES241018-0010&org=v11...
# Processing showReportPublic?folderNo=ES241018-0015&org=v11...
# Processing showReportPublic?folderNo=ES241018-0016&org=v11...
# Processing showReportPublic?folderNo=ES241018-0014&org=v11...
# Processing showReportPublic?folderNo=ES241018-0012&org=v11...
# Processing showReportPublic?folderNo=ES241018-0011&org=v11...
# Processing showReportPublic?folderNo=ES241017-0044&org=v11...
# Processing showReportPublic?folderNo=ES241017-0043&org=v11...
# Processing showReportPublic?folderNo=ES241016-0089&org=v11...
# Processing showReportPublic?folderNo=ES241016-0052&org=v11...
# Processing showReportPublic?folderNo=ES241016-0051&org=v11...
# Processing showReportPublic?folderNo=ES241016-0090&org=v11...
# Processing showReportPublic?folderNo=ES241014-0008&org=v11...
# Processing showReportPublic?folderNo=ES241114-0073&org=v11...
# Processing showReportPublic?folderNo=ES241106-0046&org=v11...
# Processing showReportPublic?folderNo=ES241106-0045&org=v11...
# Processing showReportPublic?folderNo=ES250626-0066&org=v11...
# Processing showReportPublic?folderNo=ES250624-0068&org=v11...
# Processing showReportPublic?folderNo=ES250618-0072&org=v11...
# Processing showReportPublic?folderNo=ES250612-0057&org=v11...
# Processing showReportPublic?folderNo=ES250611-0079&org=v11...
# Processing showReportPublic?folderNo=ES250605-0063&org=v11...
# Processing showReportPublic?folderNo=ES250529-0067&org=v11...
# Processing showReportPublic?folderNo=ES250529-0066&org=v11...
# Processing showReportPublic?folderNo=ES250528-0045&org=v11...
# Processing showReportPublic?folderNo=ES250521-0051&org=v11...
# Processing showReportPublic?folderNo=ES250513-0037&org=v11...
# Processing showReportPublic?folderNo=ES250225-0058&org=v11...
# Processing showReportPublic?folderNo=ES241127-0045&org=v11...
# Processing showReportPublic?folderNo=ES241127-0070&org=v11...
# Processing showReportPublic?folderNo=ES241108-0015&org=v11...
# Processing showReportPublic?folderNo=ES241031-0129&org=v11...
# Processing showReportPublic?folderNo=ES241025-0010&org=v11...
# Processing showReportPublic?folderNo=ES241025-0008&org=v11...
# Processing showReportPublic?folderNo=ES241025-0009&org=v11...
# Processing showReportPublic?folderNo=ES241024-0061&org=v11...
# Processing showReportPublic?folderNo=ES241023-0079&org=v11...
# Processing showReportPublic?folderNo=ES241023-0080&org=v11...
# Processing showReportPublic?folderNo=ES241023-0078&org=v11...
# Processing showReportPublic?folderNo=ES241018-0017&org=v11...
# Processing showReportPublic?folderNo=ES241018-0018&org=v11...
# Processing showReportPublic?folderNo=ES241018-0013&org=v11...
# Processing showReportPublic?folderNo=ES241017-0045&org=v11...
# Processing showReportPublic?folderNo=ES241016-0091&org=v11...
# Processing showReportPublic?folderNo=ES241015-0049&org=v11...

# %%
# Write to CSV
with open("ecoli_report_hurricane.csv", mode="w", newline="") as f:
    writer = csv.DictWriter(f, fieldnames=extracted_text.keys())
    writer.writeheader()
    for sample in all_data:
        writer.writerow(sample)

print("ecoli_report_hurricane.csv created successfully")
# Out:
# ecoli_report.csv created successfully

# %% [markdown]
# Manually edited **ecoli_report_hurricane.csv** to create **ecoli_clean_hurricane.csv**. The edits are described in the notes below.
#
# Notes:
# - Corrected System_Name by removing extra capitalized letter at the end of the string
# - Deleted irrelevant columns: Date_Received, Time_Received, Colilert Method, Total_Coliform_Date, and Ecoli_Date
# - Deleted samples with treated water -> also deleted Treatment and Days_Since_Treatment columns
# - Added Street_Address_Concat for geocoding which concatenates Street_Address, City, State, and Zip columns
# - Entered County, State, and Zip data for '56 Fox Hill Rd' (StarLiMS_ID = ES250108-0061)

# %%
# Set up Geocodio client
GEOCODIO_API_KEY = '7001d7bec0fe8e04c07b84e6ec76664b0876076'
client = GeocodioClient(GEOCODIO_API_KEY)

# Forward geocode the Street_Address_Concat column from 'ecoli_clean_hurricane.csv' 
df = pd.read_csv('ecoli_clean_hurricane.csv')
street_addresses = df['Street_Address_Concat'].tolist()
# print(street_addresses)

geocoded = client.batch_geocode(street_addresses)
lat = []
lng = []
accuracy = []
accuracy_type = []

for i, result in enumerate(geocoded):
    lat.append(result['results'][0]['location']['lat'])
    lng.append(result['results'][0]['location']['lng'])
    accuracy.append(result['results'][0]['accuracy'])
    accuracy_type.append(result['results'][0]['accuracy_type'])

    # Geocod.io accuracy score documentation: https://www.geocod.io/docs/?python#accuracy-score
    if result['results'][0]['accuracy'] < 0.8:
        print(f"Warning: Geocoding accuracy for {street_addresses[i]} is {result['results'][0]['accuracy']}. Accuracy type is {result['results'][0]['accuracy_type']}.")

# Write the geocoded coordinates (latitude, longitude) to 'ecoli_coords_hurricane.csv' file
df['Latitude'] = lat
df['Longitude'] = lng
df['Accuracy'] = accuracy
df['Accuracy_Type'] = accuracy_type

df.to_csv('ecoli_coords_hurricane.csv', index=False)
# Out:
# Warning: Geocoding accuracy for 1310 21N, Sparta, NC 28675 is 0.5. Accuracy type is place.
# Warning: Geocoding accuracy for 3490 Chestnut Grove, Sparta, NC 28675 is 0.6. Accuracy type is street_center.
# Warning: Geocoding accuracy for 11567 NC Hwy 88 W, Warrensville, NC 28693 is 0.7. Accuracy type is rooftop.
# Warning: Geocoding accuracy for 126 Lawrence Mtn Estates Dr, Todd, NC 28684 is 0.5. Accuracy type is nearest_rooftop_match.
# Warning: Geocoding accuracy for 16978 NC Hwy 88, Creston, NC 28615 is 0.62. Accuracy type is rooftop.
# Warning: Geocoding accuracy for 1871 Lyalls Ln, Jefferson, NC 28640 is 0.7. Accuracy type is street_center.
# Warning: Geocoding accuracy for 1947 NC Hwy 16 W, Crumpler, NC 28617 is 0.62. Accuracy type is rooftop.
# Warning: Geocoding accuracy for 19960 NC Hwy 88 W, Creston, NC 28615 is 0.7. Accuracy type is rooftop.
# Warning: Geocoding accuracy for 21861 NC Hwy 88 W, Zionville, NC 28698 is 0.7. Accuracy type is rooftop.
# Warning: Geocoding accuracy for 21861 NC Hwy 88 W, Zionville, NC 28698 is 0.7. Accuracy type is rooftop.
# Warning: Geocoding accuracy for 294 A1 Blevins Rd, Lansing, NC 28643 is 0.5. Accuracy type is place.
# Warning: Geocoding accuracy for 294 A1 Blevins Rd, Lansing, NC 28643 is 0.5. Accuracy type is place.
# Warning: Geocoding accuracy for 3765 3 Top Rd, Todd, NC 28684 is 0.5. Accuracy type is place.
# Warning: Geocoding accuracy for 5218 NC Hwy 88 E, Jefferson, NC 28640 is 0.7. Accuracy type is rooftop.
# Warning: Geocoding accuracy for 6612 NC Hwy 16 South, Jefferson, NC 28640 is 0.7. Accuracy type is rooftop.
# Warning: Geocoding accuracy for 665 Wm T Calloway Rd, Todd, NC 28684 is 0.5. Accuracy type is place.
# Warning: Geocoding accuracy for 8645 NC Hwy 163, West Jefferson, NC 28694 is 0.7. Accuracy type is rooftop.
# Warning: Geocoding accuracy for 966 Parker Rd, Lansing, NC 28643 is 0.5. Accuracy type is place.
# Warning: Geocoding accuracy for 6244 Hwy 126, Nebo, NC 28761 is 0.77. Accuracy type is range_interpolation.
# Warning: Geocoding accuracy for 3255 Nebron Rd, Hendersonville, NC 28739 is 0.5. Accuracy type is place.
# Warning: Geocoding accuracy for 56 Fox Hill Rd, ,   is 0.5. Accuracy type is place.
# Warning: Geocoding accuracy for 655 Breechwood Lakes Dr, Hendersonville, NC 28792 is 0.78. Accuracy type is rooftop.
# Warning: Geocoding accuracy for 7526 Bobs Creek Rd, Zirconia, NC 28790 is 0.7. Accuracy type is street_center.
# Warning: Geocoding accuracy for O Landria Dr, Hendersonville, NC 28739 is 0.6. Accuracy type is street_center.
# Warning: Geocoding accuracy for GWO - 100353, Charlotte, NC 28208 is 0.5. Accuracy type is place.
# Warning: Geocoding accuracy for GWO - 100353, Charlotte, NC 28208 is 0.5. Accuracy type is place.
# Warning: Geocoding accuracy for 7187 NC 261, Bakersville, NC 28705 is 0.77. Accuracy type is range_interpolation.
# Warning: Geocoding accuracy for 1 Hawk Ridge Ct, Mill Spring, NC 28756 is 0.73. Accuracy type is nearest_rooftop_match.
# Warning: Geocoding accuracy for 3109 Hwy 9N, Mill Spring, NC 28756 is 0.5. Accuracy type is place.
# Warning: Geocoding accuracy for 455 Whipper Whill Ln, Waynesville, NC 28786 is 0.52. Accuracy type is street_center.
# Warning: Geocoding accuracy for Hawk Ridge Dr (P55-299), Mill Spring, NC 28756 is 0.77. Accuracy type is nearest_rooftop_match.
# Warning: Geocoding accuracy for Hwy 9N, Mill Spring, NC 28756 is 0.5. Accuracy type is place.
# Warning: Geocoding accuracy for Marina Dr, Mill Spring, NC 28756 is 0.5. Accuracy type is place.
# Warning: Geocoding accuracy for Mountain Parkway, Mill Spring, NC 28756 is 0.5. Accuracy type is place.
# Warning: Geocoding accuracy for Mtn Parkway, Mill Spring, NC 28756 is 0.5. Accuracy type is place.
# Warning: Geocoding accuracy for Mtn Parkway, Mill Spring, NC 28756 is 0.5. Accuracy type is place.
# Warning: Geocoding accuracy for Mtn Parkway, Mill Spring, NC 28756 is 0.5. Accuracy type is place.
# Warning: Geocoding accuracy for Mtn Parkway, Mill Spring, NC 28756 is 0.5. Accuracy type is place.
# Warning: Geocoding accuracy for Mtn Pkwy, Mill Spring, NC 28756 is 0.5. Accuracy type is place.
# Warning: Geocoding accuracy for Mtn Pkwy, Mill Spring, NC 28756 is 0.5. Accuracy type is place.
# Warning: Geocoding accuracy for Mtn Pkwy, Mill Spring, NC 28756 is 0.5. Accuracy type is place.
# Warning: Geocoding accuracy for Mtn Pkwy, Mill Spring, NC 28756 is 0.5. Accuracy type is place.
# Warning: Geocoding accuracy for Mtn Pkwy, Mill Spring, NC 28756 is 0.5. Accuracy type is place.
# Warning: Geocoding accuracy for Mtn Pkwy, Mill Spring, NC 28756 is 0.5. Accuracy type is place.
# Warning: Geocoding accuracy for N Coast Dr, Mill Spring, NC 28756 is 0.5. Accuracy type is place.
# Warning: Geocoding accuracy for N Coast Dr, Mill Spring, NC 28756 is 0.5. Accuracy type is place.
# Warning: Geocoding accuracy for Parkway North, Mill Spring, NC 28756 is 0.5. Accuracy type is place.
# Warning: Geocoding accuracy for Parkway North, Mill Spring, NC 28756 is 0.5. Accuracy type is place.
# Warning: Geocoding accuracy for Parkway North, Mill Spring, NC 28756 is 0.5. Accuracy type is place.
# Warning: Geocoding accuracy for Parkway North  (Lake Adger), Mill Spring, NC 28756 is 0.5. Accuracy type is place.
# Warning: Geocoding accuracy for Parkway North (Lake Adger), Mill Spring, NC 28756 is 0.5. Accuracy type is place.
# Warning: Geocoding accuracy for Parkway North (Lake Adger), Mill Spring, NC 28756 is 0.5. Accuracy type is place.
# Warning: Geocoding accuracy for Twin Maple Way, Mill Spring, NC 28756 is 0.5. Accuracy type is place.
# Warning: Geocoding accuracy for 125 The Slade Road, Boone, NC 28607 is 0.5. Accuracy type is place.
# Warning: Geocoding accuracy for 194 Aho Rd, Blowing Rock, NC 28605 is 0.77. Accuracy type is nearest_rooftop_match.
# Warning: Geocoding accuracy for 2261 G Hayes Rd, Boone, NC 28607 is 0.7. Accuracy type is street_center.
# Warning: Geocoding accuracy for 322 Solomons Way, Vilas, NC 28692 is 0.66. Accuracy type is nearest_rooftop_match.
# Warning: Geocoding accuracy for 333 Casey's Gap Rd, Banner Elk, NC 28604 is 0.78. Accuracy type is nearest_rooftop_match.
# Warning: Geocoding accuracy for 3678 NC Hwy 194S, Sugar Grove, NC 28679 is 0.62. Accuracy type is rooftop.
# Warning: Geocoding accuracy for 370 New River Crossing, Boone, NC 28607 is 0.7. Accuracy type is rooftop.
# Warning: Geocoding accuracy for 3796 NC Hwy 194S, Sugar Grove, NC 28679 is 0.62. Accuracy type is rooftop.
# Warning: Geocoding accuracy for 3796 NC Hwy 196 S, Sugar Grove, NC 28679 is 0.5. Accuracy type is place.
# Warning: Geocoding accuracy for 3847 Mtn Dale Rd, Vilas, NC 28692 is 0.6. Accuracy type is street_center.
# Warning: Geocoding accuracy for 504 Frank Mast Rd, Valle Crucis, NC 28691 is 0.5. Accuracy type is place.
# Warning: Geocoding accuracy for 5457 NC Hwy 194 S, Banner Elk, NC 28604 is 0.7. Accuracy type is rooftop.
# Warning: Geocoding accuracy for 6000 NC Hwy 194 S, Banner Elk, NC 28604 is 0.7. Accuracy type is rooftop.
# Warning: Geocoding accuracy for 707 Mtn View Baptist Ch Rd, Deep Gap, NC 28618 is 0.46. Accuracy type is nearest_rooftop_match.
# Warning: Geocoding accuracy for 7202 NC Hwy 194 N, Boone, NC 28607 is 0.56. Accuracy type is nearest_rooftop_match.
# Warning: Geocoding accuracy for 851 Old US Highway 921, Sugar Grove, NC 28679 is 0.5. Accuracy type is place.
# Warning: Geocoding accuracy for 985 Lower Gap Ridge, Boone, NC 28607 is 0.5. Accuracy type is place.
# Warning: Geocoding accuracy for 3267 Lickillet Rd, Burnsville, NC 28714 is 0.57. Accuracy type is street_center.
# Warning: Geocoding accuracy for 9971 Hwy 805, Burnsville, NC 28714 is 0.5. Accuracy type is place.
